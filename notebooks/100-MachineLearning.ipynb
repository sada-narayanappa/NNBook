# %%
# %load_ext autoreload
# %autoreload 2
try:       importlib.reload(Jupytils);
except:    import Jupytils

from sklearn.linear_model import LinearRegression
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# ddiv.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function setSiteHeight(){
#     tHeight=0
#     $('div.output_subarea').each(function(i,e){
#         //console.log('sada', i, e, $(this).outerHeight() )
#         if ($(this).outerHeight() < 11) {
#             $(this).css('display', 'none')
#             $(this).css('outerHeight', '0px')
#         } else {
#             tHeight += $(this).outerHeight()
#         }
#     })
#     console.log('height', tHeight)
#     $("#site").css('height', tHeight +'px')
# }
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','90%')
#         //setSiteHeight()
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','100%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start=0){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <style>
# .sortdnafter:after { content: "\2193"}
# .sortupafter:after { content: "\2191";}
# .sortdnbefore:before { content: "\2193"}
# .sortupbefore:before { content: "\2191";}
# </style>
#
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
#
# function ExcecuteAllCells(content){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     start = 0;
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( code.startsWith(content)) {
#             console.log("Executing: " + cell);
#             cell.execute()
#         }
#         start += 1
#         cell = Jupyter.notebook.get_cell(start);
#     }
# }
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i > 0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     nRows = $(tableID).find('tr:last').index()+1
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, nRows )
#     cb = UpdateTableShowRows.bind(null, nRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function TableRefresh(tableID) {
#     nRows = $(tableID).find('tr:last').index()+1
#     last = $(tableID).find('th:last').text()
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRo

# %% [markdown]
# # Machine Learning Notes
#
# ### Introduction
#
# What is Machine Learning?
#
# * Supervised Learning
# * Unsupervised learning
# * Classfication
# * Regression
# * Clustering
# * Analysis
# * Parametric
# * Non-parametric
# ----
# * Feature scaling
# * polynomial features

# %% [markdown]
# ## Linear Regression
#
# Hypothesis: $h(x) = \theta^T x = \theta_0 + \theta_1 * x_1 + \theta_2 * x_2 + ... \theta_n * x_n$
#
# $h(X) = y $
#
# Error function $ J(\theta) = \frac{1}{2m} \sum_{i=0}^{m} (h(x_i) -y_i)^2)$
#
# The update rule for gradient decent is,
# $$\frac{\partial}{\partial\theta_{j}}J(\theta) =\sum_{i=1}^{m}(h_\theta(x^{i})-y^i)x_j^i $$
#
# Here $ h(x_i)$ is the value hypothesis function predicts
#
# In Linear-Regression models, one hypothesizes the population is comes from a linear model.
# <br/>The learning algorithm will find a set of parameters $\theta$ such that the error function is minimized.
#
#
# ### Practical tips to make linear regression faster
#
# * Use feature scaling - normalize and standardize all features between -1 and 1 (or something -3 to +3)
# <br/>This will make the gradient decent runs faster
# <br/>Different type is feature scalings are (normalizing) or mean normalization (divide by mean)
#
# * Learning rate: play around the idea of learning rate - use the larger learning rate and changing when solution is converging.
# <br/>Learing rate is used to scale the value to slightly adjust the weight
#
# * Manufacture new features
# <br/> For ex. in house prediction, instead of house length and width, you may add $ area = l \times w $
# <br/> If the scatter plot is not exactly  linear, consider adding squared or cubic value of features $f = x + x^2 + x^3 + \sqrt{x}$

# %%
# Here is an example of linear regression

X = np.vstack([ 1000, 1500, 1750, 2000, 2200, 2750, 1000, 1500, 1750, 2000, 2200, 2750, 1000, 1500, 1750, 2000, 2200, 2750])
y = np.array([ 120000, 150075, 178990, 271000, 224040, 272350, 102300, 170230, 172350, 200230, 220320, 234750, 123000, 
      132300, 173250, 203700, 232200, 242750])

lm = LinearRegression()
lm.fit(X, y)

print ("Intercept:" , lm.intercept_, " Coeff: ", lm.coef_)

yp = lm.predict(X)

plt.scatter(X, y,  alpha=1, marker='x', s=60, c = 'r')
plt.scatter(X, yp, alpha=1, marker='+', s=60, c = 'b')
plt.plot(X, yp , color='g',linewidth=2)
plt.show()
# Out:
# Intercept: 34871.69354838715  Coeff:  [83.22]

# %% [markdown]
# <hr>
# ## A concrete example
#
# Boston House Prices dataset
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $$10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $$1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# http://archive.ics.uci.edu/ml/datasets/Housing
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# **References**
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.
#    - many more! (see http://archive.ics.uci.edu/ml/datasets/Housing)

# %%
# Concreate example of linear regression

from sklearn.datasets import load_boston

boston = load_boston()
# You can see the dcrption of the dataset by uncommenting the following line
# print (boston.DESCR)
X = boston.data
y = boston.target

df = pd.DataFrame(X, columns = boston.feature_names)
o=displayDFs(df)
# Out:
# <table wwidth=100% style='vertical-align: top;'><tr><td style='text-align:left;' bgcolor=#ffffff>506x13 var: DFF_PY_VAR_tableID_1579400620071<br>
# <div id='tab_tableID_1579400620071' style='ddisplay:none;width:100%' >
#             <table id='tableID_1579400620071' cellpadding=0 cellspacing=0 wwidth=100% border="1" class='ourTableStyle' >
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CRIM</th>
#       <th>ZN</th>
#       <th>INDUS</th>
#       <th>CHAS</th>
#       <th>NOX</th>
#       <th>RM</th>
#       <th>AGE</th>
#       <th>DIS</th>
#       <th>RAD</th>
#       <th>TAX</th>
#       <th>PTRATIO</th>
#       <th>B</th>
#       <th>LSTAT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td style='white-space: nowrap;' contenteditable >0.006</td>
#       <td style='white-space: nowrap;' contenteditable >18.000</td>
#       <td style='white-space: nowrap;' contenteditable >2.310</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.538</td>
#       <td style='white-space: nowrap;' contenteditable >6.575</td>
#       <td style='white-space: nowrap;' contenteditable >65.200</td>
#       <td style='white-space: nowrap;' contenteditable >4.090</td>
#       <td style='white-space: nowrap;' contenteditable >1.000</td>
#       <td style='white-space: nowrap;' contenteditable >296.000</td>
#       <td style='white-space: nowrap;' contenteditable >15.300</td>
#       <td style='white-space: nowrap;' contenteditable >396.900</td>
#       <td style='white-space: nowrap;' contenteditable >4.980</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td style='white-space: nowrap;' contenteditable >0.027</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >7.070</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.469</td>
#       <td style='white-space: nowrap;' contenteditable >6.421</td>
#       <td style='white-space: nowrap;' contenteditable >78.900</td>
#       <td style='white-space: nowrap;' contenteditable >4.967</td>
#       <td style='white-space: nowrap;' contenteditable >2.000</td>
#       <td style='white-space: nowrap;' contenteditable >242.000</td>
#       <td style='white-space: nowrap;' contenteditable >17.800</td>
#       <td style='white-space: nowrap;' contenteditable >396.900</td>
#       <td style='white-space: nowrap;' contenteditable >9.140</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td style='white-space: nowrap;' contenteditable >0.027</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >7.070</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.469</td>
#       <td style='white-space: nowrap;' contenteditable >7.185</td>
#       <td style='white-space: nowrap;' contenteditable >61.100</td>
#       <td style='white-space: nowrap;' contenteditable >4.967</td>
#       <td style='white-space: nowrap;' contenteditable >2.000</td>
#       <td style='white-space: nowrap;' contenteditable >242.000</td>
#       <td style='white-space: nowrap;' contenteditable >17.800</td>
#       <td style='white-space: nowrap;' contenteditable >392.830</td>
#       <td style='white-space: nowrap;' contenteditable >4.030</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td style='white-space: nowrap;' contenteditable >0.032</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >2.180</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.458</td>
#       <td style='white-space: nowrap;' contenteditable >6.998</td>
#       <td style='white-space: nowrap;' contenteditable >45.800</td>
#       <td style='white-space: nowrap;' contenteditable >6.062</td>
#       <td style='white-space: nowrap;' contenteditable >3.000</td>
#       <td style='white-space: nowrap;' contenteditable >222.000</td>
#       <td style='white-space: nowrap;' contenteditable >18.700</td>
#       <td style='white-space: nowrap;' contenteditable >394.630</td>
#       <td style='white-space: nowrap;' contenteditable >2.940</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td style='white-space: nowrap;' contenteditable >0.069</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >2.180</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.458</td>
#       <td style='white-space: nowrap;' contenteditable >7.147</td>
#       <td style='white-space: nowrap;' contenteditable >54.200</td>
#       <td style='white-space: nowrap;' contenteditable >6.062</td>
#       <td style='white-space: nowrap;' contenteditable >3.000</td>
#       <td style='white-space: nowrap;' contenteditable >222.000</td>
#       <td style='white-space: nowrap;' contenteditable >18.700</td>
#       <td style='white-space: nowrap;' contenteditable >396.900</td>
#       <td style='white-space: nowrap;' contenteditable >5.330</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td style='white-space: nowrap;' contenteditable >0.030</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >2.180</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.458</td>
#       <td style='white-space: nowrap;' contenteditable >6.430</td>
#       <td style='white-space: nowrap;' contenteditable >58.700</td>
#       <td style='white-space: nowrap;' contenteditable >6.062</td>
#       <td style='white-space: nowrap;' contenteditable >3.000</td>
#       <td style='white-space: nowrap;' contenteditable >222.000</td>
#       <td style='white-space: nowrap;' contenteditable >18.700</td>
#       <td style='white-space: nowrap;' contenteditable >394.120</td>
#       <td style='white-space: nowrap;' contenteditable >5.210</td>
#     </tr>
#   </tbody>
# </table>
# <div style="display:block;height:20px">
#
# <input id='tableID_1579400620071_goto' type=text value=''  size=4
# onkeyup = "if (event.keyCode == 13) TableShowRows( $(this).val(), 6, '#tableID_1579400620071')">
#
# <input type=button value='<<' onclick="Page( 1, 6, '#tableID_1579400620071' );">
# <input type=button value='>>' onclick="Page( 0, 6, '#tableID_1579400620071' );">
#
# <input type=button value='Save' onclick="SaveDataFrameFromHTML('#tableID_1579400620071', 'DFF_PY_VAR_tableID_1579400620071');">
# <input type=button value='&#x21bb;' onclick="ResetToOrig('#tableID_1579400620071');">
# <input type=button value='Search>' onclick="SearchDataFrame('DFF_PY_VAR_tableID_1579400620071', '#tableID_1579400620071', 6);">
# <input id='tableID_1579400620071_search' type=text value=''" size=10
#     title="RE search support: ex: ^13$\b to search for 13"
#     onkeyup = "if (event.keyCode == 13) SearchDataFrame('DFF_PY_VAR_tableID_1579400620071', '#tableID_1579400620071', 6);">
# </div>
# <script>
# AddFocus('#tableID_1579400620071', 6);
# SetSort('#tableID_1579400620071');
# AddClickCB('#tableID_1579400620071', null);
# $("#tableID_1579400620071 th").resizable()
#
# </script>
#
#             <div id='tableID_1579400620071_searchResults'></div>
#             </div></td></tr></table>

# %%
lm = LinearRegression()
lm.fit(X, y)
# print the R-squared
print("The R-squared value is: {0:0.4f} \n".format(lm.score(X, y)))

# save intercept and coefficients
param_df = pd.DataFrame({"Features": ['intercept'] + list(boston.feature_names), "Coef": [lm.intercept_] + list(lm.coef_)})
cols = param_df.columns.tolist()
cols = cols[-1:]+cols[:-1]
param_df = param_df[cols]
display(HTML(param_df.to_html()));
# Out:
# The R-squared value is: 0.7406
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Coef</th>
#       <th>Features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>36.459</td>
#       <td>intercept</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.108</td>
#       <td>CRIM</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.046</td>
#       <td>ZN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.021</td>
#       <td>INDUS</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.687</td>
#       <td>CHAS</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-17.767</td>
#       <td>NOX</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3.810</td>
#       <td>RM</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.001</td>
#       <td>AGE</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-1.476</td>
#       <td>DIS</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.306</td>
#       <td>RAD</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>-0.012</td>
#       <td>TAX</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.953</td>
#       <td>PTRATIO</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>0.009</td>
#       <td>B</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>-0.525</td>
#       <td>LSTAT</td>
#     </tr>
#   </tbody>
# </table>

# %%
newX = X
newY = y

# predict and create a dataframe
predicted = lm.predict(newX)
predictedDf = pd.DataFrame({"predicted": predicted})
# dataframe for X
newXDf = pd.DataFrame(newX)
newXDf.columns = boston.feature_names
# dataframe for y
newYDf = pd.DataFrame(newY)
newYDf.columns = ['ActualY']
# join X, y and prediction
mydata_with_pd = newXDf.join(newYDf).join(predictedDf)

displayDFs(mydata_with_pd.head());
# Out:
# <table wwidth=100% style='vertical-align: top;'><tr><td style='text-align:left;' bgcolor=#ffffff>5x15 var: DFF_PY_VAR_tableID_1579400626792<br>
# <div id='tab_tableID_1579400626792' style='ddisplay:none;width:100%' >
#             <table id='tableID_1579400626792' cellpadding=0 cellspacing=0 wwidth=100% border="1" class='ourTableStyle' >
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CRIM</th>
#       <th>ZN</th>
#       <th>INDUS</th>
#       <th>CHAS</th>
#       <th>NOX</th>
#       <th>RM</th>
#       <th>AGE</th>
#       <th>DIS</th>
#       <th>RAD</th>
#       <th>TAX</th>
#       <th>PTRATIO</th>
#       <th>B</th>
#       <th>LSTAT</th>
#       <th>ActualY</th>
#       <th>predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td style='white-space: nowrap;' contenteditable >0.006</td>
#       <td style='white-space: nowrap;' contenteditable >18.000</td>
#       <td style='white-space: nowrap;' contenteditable >2.310</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.538</td>
#       <td style='white-space: nowrap;' contenteditable >6.575</td>
#       <td style='white-space: nowrap;' contenteditable >65.200</td>
#       <td style='white-space: nowrap;' contenteditable >4.090</td>
#       <td style='white-space: nowrap;' contenteditable >1.000</td>
#       <td style='white-space: nowrap;' contenteditable >296.000</td>
#       <td style='white-space: nowrap;' contenteditable >15.300</td>
#       <td style='white-space: nowrap;' contenteditable >396.900</td>
#       <td style='white-space: nowrap;' contenteditable >4.980</td>
#       <td style='white-space: nowrap;' contenteditable >24.000</td>
#       <td style='white-space: nowrap;' contenteditable >30.004</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td style='white-space: nowrap;' contenteditable >0.027</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >7.070</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.469</td>
#       <td style='white-space: nowrap;' contenteditable >6.421</td>
#       <td style='white-space: nowrap;' contenteditable >78.900</td>
#       <td style='white-space: nowrap;' contenteditable >4.967</td>
#       <td style='white-space: nowrap;' contenteditable >2.000</td>
#       <td style='white-space: nowrap;' contenteditable >242.000</td>
#       <td style='white-space: nowrap;' contenteditable >17.800</td>
#       <td style='white-space: nowrap;' contenteditable >396.900</td>
#       <td style='white-space: nowrap;' contenteditable >9.140</td>
#       <td style='white-space: nowrap;' contenteditable >21.600</td>
#       <td style='white-space: nowrap;' contenteditable >25.026</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td style='white-space: nowrap;' contenteditable >0.027</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >7.070</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.469</td>
#       <td style='white-space: nowrap;' contenteditable >7.185</td>
#       <td style='white-space: nowrap;' contenteditable >61.100</td>
#       <td style='white-space: nowrap;' contenteditable >4.967</td>
#       <td style='white-space: nowrap;' contenteditable >2.000</td>
#       <td style='white-space: nowrap;' contenteditable >242.000</td>
#       <td style='white-space: nowrap;' contenteditable >17.800</td>
#       <td style='white-space: nowrap;' contenteditable >392.830</td>
#       <td style='white-space: nowrap;' contenteditable >4.030</td>
#       <td style='white-space: nowrap;' contenteditable >34.700</td>
#       <td style='white-space: nowrap;' contenteditable >30.568</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td style='white-space: nowrap;' contenteditable >0.032</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >2.180</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.458</td>
#       <td style='white-space: nowrap;' contenteditable >6.998</td>
#       <td style='white-space: nowrap;' contenteditable >45.800</td>
#       <td style='white-space: nowrap;' contenteditable >6.062</td>
#       <td style='white-space: nowrap;' contenteditable >3.000</td>
#       <td style='white-space: nowrap;' contenteditable >222.000</td>
#       <td style='white-space: nowrap;' contenteditable >18.700</td>
#       <td style='white-space: nowrap;' contenteditable >394.630</td>
#       <td style='white-space: nowrap;' contenteditable >2.940</td>
#       <td style='white-space: nowrap;' contenteditable >33.400</td>
#       <td style='white-space: nowrap;' contenteditable >28.607</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td style='white-space: nowrap;' contenteditable >0.069</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >2.180</td>
#       <td style='white-space: nowrap;' contenteditable >0.000</td>
#       <td style='white-space: nowrap;' contenteditable >0.458</td>
#       <td style='white-space: nowrap;' contenteditable >7.147</td>
#       <td style='white-space: nowrap;' contenteditable >54.200</td>
#       <td style='white-space: nowrap;' contenteditable >6.062</td>
#       <td style='white-space: nowrap;' contenteditable >3.000</td>
#       <td style='white-space: nowrap;' contenteditable >222.000</td>
#       <td style='white-space: nowrap;' contenteditable >18.700</td>
#       <td style='white-space: nowrap;' contenteditable >396.900</td>
#       <td style='white-space: nowrap;' contenteditable >5.330</td>
#       <td style='white-space: nowrap;' contenteditable >36.200</td>
#       <td style='white-space: nowrap;' contenteditable >27.944</td>
#     </tr>
#   </tbody>
# </table>
# <div style="display:block;height:20px">
#
# <input id='tableID_1579400626792_goto' type=text value=''  size=4
# onkeyup = "if (event.keyCode == 13) TableShowRows( $(this).val(), 6, '#tableID_1579400626792')">
#
# <input type=button value='<<' onclick="Page( 1, 6, '#tableID_1579400626792' );">
# <input type=button value='>>' onclick="Page( 0, 6, '#tableID_1579400626792' );">
#
# <input type=button value='Save' onclick="SaveDataFrameFromHTML('#tableID_1579400626792', 'DFF_PY_VAR_tableID_1579400626792');">
# <input type=button value='&#x21bb;' onclick="ResetToOrig('#tableID_1579400626792');">
# <input type=button value='Search>' onclick="SearchDataFrame('DFF_PY_VAR_tableID_1579400626792', '#tableID_1579400626792', 6);">
# <input id='tableID_1579400626792_search' type=text value=''" size=10
#     title="RE search support: ex: ^13$\b to search for 13"
#     onkeyup = "if (event.keyCode == 13) SearchDataFrame('DFF_PY_VAR_tableID_1579400626792', '#tableID_1579400626792', 6);">
# </div>
# <script>
# AddFocus('#tableID_1579400626792', 6);
# SetSort('#tableID_1579400626792');
# AddClickCB('#tableID_1579400626792', null);
# $("#tableID_1579400626792 th").resizable()
#
# </script>
#
#             <div id='tableID_1579400626792_searchResults'></div>
#             </div></td></tr></table>

# %%
# I am not sure why I am plotting this
## ===========Lets make some bins depending on how far or close to real 
mydata_with_pd['diff'] = mydata_with_pd['ActualY'] - mydata_with_pd['predicted'] 
mydata_with_pd['diff'].hist(bins=50)

min = floor(mydata_with_pd['diff'].min())
max = ceil(mydata_with_pd['diff'].max())
nbins=5
bins = np.linspace(min, max, nbins, endpoint=True)
group_names = []
for i in arange(len(bins[1:])):
    group_names.append ("{} - ({} - {}] ".format(i, bins[i],  bins[i+1]))

mydata_with_pd['bins'] = pd.cut(mydata_with_pd['diff'], bins, labels=group_names)
mydata_with_pd['bins'] = mydata_with_pd['bins'].astype(str)

mydata_with_pd['diff'].hist(bins=50);

# %%
dfPCA=PCAPlot(mydata_with_pd, 'bins')
# Out:
# Dropping in prepareDF -  Index([], dtype='object')

# %%
mydata_with_pd
# Out:
#      CRIM     ZN  INDUS  CHAS   NOX    RM    AGE   DIS   RAD     TAX  PTRATIO       B  LSTAT  ActualY  predicted    diff                  bins
# 0   0.006 18.000  2.310 0.000 0.538 6.575 65.200 4.090 1.000 296.000   15.300 396.900  4.980   24.000     30.004  -6.004  0 - (-16.0 - -5.25]
# 1   0.027  0.000  7.070 0.000 0.469 6.421 78.900 4.967 2.000 242.000   17.800 396.900  9.140   21.600     25.026  -3.426    1 - (-5.25 - 5.5]
# 2   0.027  0.000  7.070 0.000 0.469 7.185 61.100 4.967 2.000 242.000   17.800 392.830  4.030   34.700     30.568   4.132    1 - (-5.25 - 5.5]
# 3   0.032  0.000  2.180 0.000 0.458 6.998 45.800 6.062 3.000 222.000   18.700 394.630  2.940   33.400     28.607   4.793    1 - (-5.25 - 5.5]
# ..    ...    ...    ...   ...   ...   ...    ...   ...   ...     ...      ...     ...    ...      ...        ...     ...                   ...
# 502 0.045  0.000 11.930 0.000 0.573 6.120 76.700 2.288 1.000 273.000   21.000 396.900  9.080   20.600     22.376  -1.776    1 - (-5.25 - 5.5]
# 503 0.061  0.000 11.930 0.000 0.573 6.976 91.000 2.167 1.000 273.000   21.000 396.900  5.640   23.900     27.627  -3.727    1 - (-5.25 - 5.5]
# 504 0.110  0.000 11.930 0.000 0.573 6.794 89.300 2.389 1.000 273.000   21.000 393.450  6.480   22.000     26.128  -4.128    1 - (-5.25 - 5.5]
# 505 0.047  0.000 11.930 0.000 0.573 6.030 80.800 2.505 1.000 273.000   21.000 396.900  7.880   11.900     22.344 -10.444  0 - (-16.0 - -5.25]
#
# [506 rows x 17 columns]

# %% [markdown]
# <hr/>
# ## More advanced view
#
# The following topics are more advanced and you may want to review the following material after you have become familiar with the other topics. In fact, browse through the notes and not worry about it - you can do most of linear regression without having to learn this. Having said that, you will likely have to reread materials many times before everything sinks. I had to do it many many times and even now I forget it if I don't use it for more than few weeks.
#
# We are going to use the data used by:
# http://connor-johnson.com/2014/02/18/linear-regression-with-python/
#
# This is data from a British government survey of household spending may be used to examine the relationship between household spending on tobacco products and alcholic beverages.
#
# '''Region Alcohol Tobacco
# North 6.47 4.03
# Yorkshire 6.13 3.76
# Northeast 6.19 3.77
# East Midlands 4.89 3.34
# West Midlands 5.63 3.47
# East Anglia 4.52 2.92
# Southeast 5.89 3.20
# Southwest 4.79 2.71
# Wales 5.27 3.53
# Scotland 6.08 4.51
# Northern Ireland 4.02 4.56'''

# %%
import sys
import importlib as imp
if ('Jupytils' in sys.modules):
    reloaded = imp.reload(Jupytils)
else:
    import Jupytils
    
data='''Region Alcohol Tobacco
North 6.47 4.03
Yorkshire 6.13 3.76
Northeast 6.19 3.77
East-Midlands 4.89 3.34
West-Midlands 5.63 3.47
East-Anglia 4.52 2.92
Southeast 5.89 3.20
Southwest 4.79 2.71
Wales 5.27 3.53
Scotland 6.08 4.51
Northern-Ireland 4.02 4.56'''

df  = LoadDataSet(data, seperator=" ");
df['Alcohol']=df.Alcohol.astype(float)
df['Tobacco']=df.Tobacco.astype(float)

X=df[['Tobacco']].as_matrix()
y=df.Alcohol.values

## -----
lm = LinearRegression()
lm.fit(X, y)

print ("Intercept:" , lm.intercept_, " Coeff: ", lm.coef_)

yp = lm.predict(h)

plt.scatter(X, y,  alpha=1, marker='x', s=60, c = 'r')
plt.scatter(X, yp, alpha=1, marker='+', s=60, c = 'b')
plt.plot(X, yp , color='g',linewidth=2)
plt.xlabel('Tobacco', fontsize=18)
plt.ylabel('Alcohol', fontsize=16)
# Out:
# <style>
# body {
#     font-family: "Lucida Grande", "Lucida Sans Unicode", verdana, geneva, sans-serif;
#     font-size: 10pt;
# }
#
# CodeMirror-gutters {
#     border-right: 0px solid #ddd;
#     background-color: #f7f7f7;
#     white-space: nowrap;
# }
#
# div.output {
#     border: 0px;
# }
#
# div.output_subarea {
#     padding: 0.4em;
#     max-width: calc(100% - 0ex);
#     border: 0px white solid;
# }
#
# div.cell.rendered {
#     border: 0px;
# }
#
# div.cell.code_cell.rendered.selected {
#     background: rgba(0, 0, 0, 0)
# }
#
# div#notebook{
#     font-size: 12px;
#     padding-top: 0px;
# }
# .CodeMirror {
#     font-size: 12px;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 12px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     font-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
#   padding: 10px 10px;
#   font-family: sans-serif;
# }
#
# h5 {
#     padding-top: 8px;
#     padding-botton: 8px;
#     border-top:    1px solid gray;
#     border-bottom: 2px solid gray;
# }
#
# h6 {
#     padding-top: 14px;
#     padding-botton: 16px;
#     border-top:    2px solid #cccccc;
#     border-bottom: 2px solid #cccccc;
# }
#
# .thumbnail  {
#     position: relative;
#     float: left;
#     padding: 0px;
#     z-index: 3;
#     text-align: center;
# }
#
# .thumbnail:hover {
#     background-color: #e9e9e2;
#     color: #335500;
#     text-decoration: none;
# }
#
# .thumbnail span { /*CSS for enlarged image*/
#     position: fixed;
#     opacity: 1.5;
#     background-color: #e5e5e5;
#     padding: 5px;
#     border: 1px solid #666;
#     visibility: hidden;
#     color: black;
#     text-decoration: none;
#     text-align: center;
#     top:  150px; /* use IF IE6 style to correct IE6 positions of larger image relative to thumb */
#     right: 50px;/*position where enlarged image should offset horizontally */
#     z-index: 9999;
#     filter: alpha(opacity=100);
# }
#
# .thumbnail:hover span { /*CSS for enlarged image on hover*/
#     visibility: visible;
#     width: 500px;
# }
#
# .container { width: 100% !important; }
#     div.cell{
#         width:100%;
#         margin-left:0%;
#         margin-right:auto;
# }
#
# div.cell.selected{
#   border: '0px';
# }
# .cell.selected{
#   border: '0px';
# }
# ddiv.prompt {display: none}
#
# .prompt {
#     min-width: 4ex;
#     height: 20%;
# }
#
# .CodeMirror-gutters {
#     border-bottom-left-radius: 2px;
#     border-top-left-radius: 2px;
#     border-left: 5px solid #336699;
# }
#
#
#
# <style>
# .ourTableStyle {
#     width:100%;
#     bborder-left:#000000 0px solid;
#     border-collapse:collapse;
#     border-collapse: collapse;
#     padding: 0px;
#     margin: 0px;
# }
# .ourTableStyle th {
#     background-color: #ededed;
#     border-top: 1px black solid;
#     border-bottom:#000000 1px solid;
#     border-right:#dddddd 1px solid;
#     text-align: center;
#     padding: 5px;
#     margin-left: 5px;
#     wwidth: 10px;
# }
#
# .ourTableStyle tr:nth-child(even) {
#     background-color: #ffffff;
# }
# .sadaTable tr:nth-child(odd) {
#     background-color: #ffffff;
# }
#
#
# .ourTableStyle td{
#     bbackground-color: #000000;
#     border-right:#dddddd 1px solid;
#     border-bottom:#dddddd 1px solid;
#     bborder-top:#eeeeee 1px solid;
#     padding: 7px;
#     margin: 3px;
#     text-align: left;
# }
#
# .dataframe td{
#     text-align: left;
# }
#
# </style>
#
#
# <script>
# function log(e) {
#     console.log(e)
#
# }
#
# function toggleDiv(divId) {
#    $("#"+divId).toggle();
#
# }
# </script>
# <!-- --------------------------------------------- HTML UTILITIES ARE HERE =-------------------------- -->
# <script>
# //$("site").css('height', '100%')
# //$("#site").css('height', '100%')
# //$("#notebook.container").css('padding-top', '80px')
# var oo=null;
# function ToggleCode(code_show){
#     showHide = (code_show) ? "block": "none"
#     $('div.input').each(function(i){
#         if (i >= 0){
#             //console.log(this)
#             $(this).css('display', showHide);
#             return
#         }
#     });
#
#     $('div.output').each(function(i){
#         oo=this
#         if (code_show ||  oo.textContent.length > 0 ){
#             console.log(oo.textContent.length)
#             //$(this).css('display', showHide);
#             $(this).css('border', '0px');
#             return
#         }
#     });
# }
#
# code_show=false;
# function ToggleEle(element) {
#     $('div.cell.rendered').css('border','0px')
#
#     if (code_show){
#         $(element).css('display', 'block');
#         $("#site").css('height','90%')
#     } else {
#         $(element).css('display', 'none');
#         $("#site").css('height','100%')
#     }
#     ToggleCode(code_show)
#
#     code_show = !code_show
#
# }
#
# function NtoggleOld(){
#     ToggleEle('#header')
#     if (code_show){
#         $('#HTMLTopBar').css('position', 'fixed')
#     } else {
#         $('#HTMLTopBar').css('position', '')
#
#     }
# }
# //**************** ALL OF THE ABOVE CAN BE DELETED IF THE FOLLOWING WORKS
# var oldcodeRednderedStyle=null;
#
# function setSiteHeight(){
#     tHeight=0
#     $('div.output_subarea').each(function(i,e){
#         //console.log('sada', i, e, $(this).outerHeight() )
#         if ($(this).outerHeight() < 11) {
#             $(this).css('display', 'none')
#             $(this).css('outerHeight', '0px')
#         } else {
#             tHeight += $(this).outerHeight()
#         }
#     })
#     console.log('height', tHeight)
#     $("#site").css('height', tHeight +'px')
# }
#
# function Ntoggle(hideCode){
#     if (!oldcodeRednderedStyle){
#         oldcodeRednderedStyle = $('div.cell.code_cell.rendered.selected').css('background')
#     }
#     $("#notebook").css('padding-top','0')
#
#     if($("#header").is(":hidden")){   // It will be unhidden next
#         $("#site").css('height','90%')
#         //setSiteHeight()
#         if ( hideCode ) {
#             return // Since already hidden - just return
#         }
#     } else {
#         $("#site").css('height','100%')
#     }
#     $('div.cell.code_cell.rendered.selected').css('background', '')
#     $('#header').slideToggle( "slow" );
#     $('#HTMLTopBar').css('position', '')
#     $('div.input').slideToggle( "slow" );
#
#     window.scrollTo(-150, 0);
# }
#
# w = $('#sada_hc1')
# if (w.length <=10) {
#     w = '<input id="sada_hc1" type=button value="-" style="position: fixed; bottom:0; left:150; z-index: 9999;" onclick="Ntoggle()" />'
#     $('body').append(w)
#     $('#site').css('height', '75%');
# }
#
# ret=''
# // <form id="myform"> :
# function ReturnJSONstring(formID, py_var_name) {
#     arr = $(formID).serializeArray();
#     ret = {};
#     for (i=0; i < arr.length; i++) { ret[""+arr[i].name] = arr[i].value }
#     ret1 = JSON.stringify(ret);
#     SetPyValue(ret1, py_var_name)
#     return ret1
# }
#
# function GetFormValue(name_or_id, py_var_name) {
#     val = $(name_or_id).val() || '';
#     SetPyValue(val, py_var_name)
#     return val;
# }
#
# function SetPyValue(val, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + val)
#         return;
#     }
#     val1 = val.replace("'","\\'")
#     var command = py_var_name + " = r'''" + val1 + "'''";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     console.log("Executing Command: " + command);
#
#     return val1
# }
#
# function findAndExcecuteCell(content, start=0){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     if ( typeof(start) === "undefined")
#         start = 0
#
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( !code.startsWith(content)) {
#             start += 1
#             cell = Jupyter.notebook.get_cell(start);
#             continue;
#         }
#         cell.execute()
#         return cell
#     }
#     console.log("Could not find cell from index: " + start + "  with first line: "+ content)
#     return null;
# }
#
# //Ex: TableToJSON("#edt1", edt1={})
# function TableToJSON(tableName) {
#     ret=[]
#     var cells = $(tableName).find('tr');
#     var i = 0;
#     cells.each(function () {
#
#         var row=[]
#         $(this).each(function(){ row.push($(this).text())})
#
#         ret.push(row)
#         //console.log(i, JSON.stringify(row))
#     });
#     ret1 = JSON.stringify(ret)
#     //console.log(ret1)
#     return ret1;
# }
#
# //var command = " myVar = ( r\'\'\'" + ret1 + "\'\'\')";
# //var kernel = Jupyter.notebook.kernel;
# //kernel.execute(command);
#
# function SetPyVarValue(jValue, py_var_name) {
#     if ( typeof py_var_name !== "string" ){
#         console.log( "py_var_name must be a string : Assertion failed: " + typeof py_var_name + " : " + jValue)
#         return '';
#     }
#     //console.log(jValue)
#     var command = py_var_name + " = r\'\'\'" + jValue + "\'\'\'";
#     var kernel = Jupyter.notebook.kernel;
#     kernel.execute(command);
#     //console.log("Executing Command: " + command);
#
#     return jValue
# }
#
# /** --------------------------------------------- HTML UTILITIES ARE HERE =--------------------------*/
# </script>
# <!-- script src="http://code.jquery.com/jquery-latest.min.js" type="text/javascript"></script> -->
# <style>
# .sortdnafter:after { content: "\2193"}
# .sortupafter:after { content: "\2191";}
# .sortdnbefore:before { content: "\2193"}
# .sortupbefore:before { content: "\2191";}
# </style>
#
# <script>
# //----------------------------------------------------------------------------
# String.prototype.format = function (){
#     var args = arguments;
#     return this.replace(/\{\{|\}\}|\{(\d+)\}/g, function (curlyBrack, index) {
#         return ((curlyBrack == "{{") ? "{" : ((curlyBrack == "}}") ? "}" : args[index]));
#     });
# };
#
# //----------------------------------------------------------------------------
# var gu = {}
# gu.globalCB = null
# //----------------------------------------------------------------------------
# gu.l = function(sep, ...args){
#     var nt =''
#     for (var s in args) {
#         nt += args[s] + sep
#         console.log(s, args[s])
#     }
#     return nt;
# }
# gu.ln = function(o, ...args){
#     var ln = gu.l('<br/>', o, ...args)
#     console.log(ln)
#     return ln
# }
# gu.s = function(w, sep,...args){
#     var ln = gu.l(sep || '<br/>', ...args)
#     $('#'+w).val(ln);
# }
#
# //----------------------------------------------------------------------------
# gu.inNotebook = function() {
#     var kernel;
#     try{
#         kernel = Jupyter.notebook.kernel;
#         return kernel
#     }catch(Exception) {
#     }
#     return false
# }
#
# gu.cleanPyOut = function (out) {
#     var oup = ''
#     gu.lastJSOut = ''
#     gu.lastJSOutReady = false
#     try{
#         oup = out.content.user_expressions.out1;
#         if (typeof(oup) != "undefined") {
#             if ( oup.status === "ok" ) {
#                 var res = (oup.data && oup.data["text/plain"]) || '';
#                 var nre = res.replace(/\\n/g, '\n' )
#                 nre = nre.replace(/\\'/g, "'" )
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             } else{
#                 var nre = oup.status + " : " + oup.ename + " : " + oup.evalue + "\n" + oup.traceback
#                 gu.lastJSOut = nre
#                 gu.lastJSOutReady = true
#             }
#         }
#     } catch(e){
#         console.log("Error while excuting: " + typeof(e) )
#     }
#     if ( typeof(gu) != "undefined" ){
#         //console.log("Output: " + gu.lastJSOut)
#     }
#     return gu.lastJSOut;
# }
#
# // test: gu.callPython("45")
# // returns 45
# gu.callPython=function(cmd, cbFunc) {
#     if ( !gu.inNotebook() ) {
#         return;
#     }
#     var newCBFunc;
#     if (typeof(cbFunc) == "undefined" ) {
#         //gu.ln("**NO CALLBACL SPECIFIED")
#         cbFunc = gu.cleanPyOut
#     }
#     if ( cbFunc != gu.cleanPyOut ){
#         newCBFunc= function(out1) { out = gu.cleanPyOut(out1);  cbFunc(out); }
#     }else{
#         newCBFunc = cbFunc
#     }
# //    console.log(">>:", cmd, newCBFunc)
#     var kernel = Jupyter.notebook.kernel;
#
# //    var callbacks = {shell: {reply: cbFunc    }};
#     var callbacks = {shell: {reply: newCBFunc }};
#     //gu.ln("excuting: " + cmd)
#     kernel.execute(
#       "print('only the success/fail status of this code is reported')",
#       callbacks,
#       {user_expressions:  {out1: cmd}  }
#     );
# }
#
# gu.callPythonE=function(cmd, cbFunc) {
#     cmd1 = "eval( '''\n" + cmd + "\n''' )"
#     gu.ln(cmd)
#     gu.callPython(cmd1, cbFunc)
# }
#
# gu.ajax = function(url, cbFunc){
#     $.ajax({
#       crossOrigin: true,
#       url: url,
#       context: document.body
#     }).done(function(data, textStats, jqXHR) {
#       gu.ln(url, data)
#       if ( typeof(cbFunc) != "undefined" ) {
#           cbFunc(data, textStats, jqXHR)
#       }
#     });
# }
#
# gu.proxy = function(url, cbFunc, q, prot){
#     var PROXY = "../cgi-bin/proxy.py?url=";
#     var url = PROXY + url //+ "q=" + encodeURIComponent(q);
#     prot = prot || 'GET'
#     gu.s('status', '\n',prot, url, q, cbFunc)
#
#     $.ajax({
#       type: 'GET',
#       url:  url,
#       timeout: 2000,
#       contentType: "",
#       dataType: "text",
#       processdata: false,
#       cache: true,
#       success: function (data) {
#          somedata=data
#          cbFunc(data)
#       },
#       error: function(xhr, stat, err) {
#          var err = "Exception:  " + xhr + ": " + stat + " " + err + " ]" + xhr.responseText
#          console.log(err)
#          cbFunc(err)
#       }
#    });
# }
#
# // var url2 ="http://www.smartconnectedhealth.org/aura/webroot/db.jsp?qn=490&type=html"
# // function callBackFunc(out) { var nre = gu.cleanPyOut(out); console.log(nre); $('#status').html(nre)}
# // gu.getURL(url2, callBackFunc)
# gu.getURL = function(url,cbFunc, noproxy, params) {
#     url = url.trim();
#     if ( gu.inNotebook() ) {
#         var cmd = 'getURL("{0}")'.format(url)
#         //console.log(cmd)
#         gu.callPython(cmd, cbFunc )
#         return "InPython" ;
#     } else if( typeof(noproxy) == "undefined") {
#         gu.proxy(url, cbFunc)
#     } else {
#         gu.ajax(url, cbFunc)
#     }
# }
# gu.getCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#     }
#     return cell
# }
#
# gu.execCell = function(v){
#     var cell = Jupyter.notebook.get_cell(v);
#     var code = v+ ' Not found';
#     if ( cell) {
#         code = cell.get_text();
#         $('#status').text(code)
#         cell.execute()
#     }
#     return cell}
#
# gu.findAndExecPyCell = function(v){
# }
#
# gu.callPython($('#pycode').val(), gu.cleanPyOut);
# </script>
# <script>
# jQuery.fn.reverse = [].reverse;
#
#
# function ExcecuteAllCells(content){
#     if ( typeof content !== "string" ){
#         console.log( "content must be a string : ]=: " + typeof content)
#         return;
#     }
#     start = 0;
#     cell = Jupyter.notebook.get_cell(start);
#     while(cell) {
#         code = cell.get_text();
#         if ( code.startsWith(content)) {
#             console.log("Executing: " + cell);
#             cell.execute()
#         }
#         start += 1
#         cell = Jupyter.notebook.get_cell(start);
#     }
# }
#
# function UpdateTableShowRows( tab_maxDisp, tableID, out) {
#     if(out.length <=10)
#         return
#
#     o1 = out.slice(1, -1)
#     if (o1.startsWith("'") || o1.startsWith('"') )
#         o1 = out.slice(1, -1)
#
#     if (o1.startsWith ("error")){
#         console.log("==>Kernel Error:" + o1 );
#         return;
#     }
#
#     if ( o1.indexOf('\\\\') >= 0) {
#         o1 = o1.replace(/\\\\/g,'\\');
#         o1 = o1.replace(/\\\\/g,'\\');
#     }
#     o1 = o1.replace(/\n/g,'\\n');
#     //console.log("==>" + o1 );
#
#     try{
#         o = JSON.parse( o1 )
#     } catch(e){
#         console.log(e, out )
#     }
#     // console.log("==>" + out );
#     // console.log("==>VALS\n " + o.vals );
#     // console.log("==>IDXX " + o.idxs + " ++" + tableID);
#
#     if (o.idxs.length <=0)
#         return;
#
#     var i=0;
#     trs = '{0} th'.format(tableID)
#     //$(trs).find('th:first').each(function ()
#     //{
#     //    $(this).text( o.idxs[i++]);
#     //});
#     var i=o.idxs.length-1;
#     $(trs).reverse().each(function ()
#     {
#         if (i > 0)
#             $(this).text( o.idxs[i--]);
#         else
#             return;
#     });
#
#     i=o.vals.length-1;
#     tds = '{0} td'.format(tableID)
#     $(tds).reverse().each(function ()
#     {
#         if (i >=0)
#             $(this).text(o.vals[i--]);
#         else
#             return;
#     });
# }
#
# function TableShowRows( gg, tab_maxDisp, tableID) {
#     if (gg.length <=0 )
#         return
#
#     nRows = $(tableID).find('tr:last').index()+1
#
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     g = Number.parseInt(gg)
#     if (isNaN(g) ){
#         console.log("hmmmm value: "+ gg + " make no sense" )
#         return '';
#     }
#     command = "getHTMLTableRows({0}, startRow={1}, maxRows={2})".format(dfName, g, nRows )
#     cb = UpdateTableShowRows.bind(null, nRows, tableID)
#     gu.callPython( command, cb) ;
# //    console.log("Executing Command: " + command );
# }
#
# function TableRefresh(tableID) {
#     nRows = $(tableID).find('tr:last').index()+1
#     last = $(tableID).find('th:last').text()
#     dfName = "DFF_PY_VAR_" + tableID.substr(1);
#
#     command = "getHTMLTableRo
# Intercept: 4.351168486048509  Coeff:  [0.3]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b2cd93a8b783> in <module>
#      32 print ("Intercept:" , lm.intercept_, " Coeff: ", lm.coef_)
#      33
# ---> 34 yp = lm.predict(h)
#      35
#      36 plt.scatter(X, y,  alpha=1, marker='x', s=60, c = 'r')
#
# NameError: name 'h' is not defined

# %%
import statsmodels.formula.api as sm
from sklearn.linear_model import LinearRegression
import scipy, scipy.stats

result = sm.OLS( y, X ).fit()
result.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-096f00e0c9b3> in <module>
#       3 import scipy, scipy.stats
#       4
# ----> 5 result = sm.OLS( y, X ).fit()
#       6 result.summary()
#
# AttributeError: module 'statsmodels.formula.api' has no attribute 'OLS'
