# %%
import sys
import importlib as imp
if ('Jupytils' in sys.modules):
    reloaded = imp.reload(Jupytils)
else:
    import Jupytils
# Out:
# <script type="text/javascript" src="http://ajax.googleapis.com/ajax/libs/jquery/1.3/jquery.min.js"></script>
# <style>
# body {
#   font-family: Times 'Merriweather', Georgia, serif;
# }
#
# .imgs {
#     width: 250px;
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border: 0px gray;
# }
# .imgs1 {
#     align: left;
#     float: left;
#     padding-right: 50px;
#     padding-top: 20px;
#     border-top: 1px solid gray;
#     border-bottom: 1px solid gray;
#     margin-right: 50px;
# }
#
# hr {
#     height:3px;
#     border:none;
#     color:#333;
#     background-color:#333;"
# }
#
# p {
#   margin: 10px auto;
#   padding: 6px 10px;
#   font-weight: 300;
#   font-size: 16px;
#   line-height: 1.4;
# }
#
# h1 {
#     margin: 20px auto 0px;
#     padding: 0 10px;
#     text-align: center;
#     font-size: 80px;
#     ffont-weight: 300;
#     mmax-width: 800px;
# }
#
# h4 {
#   max-width: 800px;
#   margin: 0 auto;
# ...

# %% [markdown]
# ## What to do next
#
# ### Feature Selection
#
# * More Features - (can spend lot of time and wasted effort - easily spend 6 months)
# * Add Polynomial features
# * increase $\lambda$
# * Try smaller data
# * Try polynomial features
#
# <img src=imgs/model-selection.png class="imgs1" width=40%>

# %% [markdown]
# ## Evaluate learning Algorithms
#
# Overfitting - Fails to generalize to new examples not in training set
#
#
# Do any of the solling splits
# > Training/Test split
# > k-fold  validation
#
# compute test error and training error
#
#
# ### What degree of polynomial you can pick for prediction
# Compute $\theta$ paramters for each degree of polynomial
#
# For example:
#
# <img src=imgs/model-selection.png class="imgs1" width=30%>
# As shown in the picture.
# 1. shows 1 degree polynomial
# 2. second degree of polynomail
# etc.
#
# Now split the data into a) training b) validation c) test set
#
# 1. First train on a degree of polynomial;
# 2. Adjust the degree polynomail using the cross validation
# 3. test the resulting on the test set
#
# <br/>
#
#
# ### Bias/Variance (Underfitting/Overfitting)
#
# <img src=imgs/bias-ex.png  width=80%>
#
# ##### Regularization Bias and Variance
# <img src=imgs/bias-regularization.PNG  width=50%>
#
# -----
#
# <img src=imgs/bias-trainingexamples.PNG  width=50%>
#
# ## Machine learning diagnostics
